# %%
def validate_pin(pin):

  res = ''
  count = 0
  flag_digi = 0


  for i in pin:
       count = count + 1

       if i not in ['1','3','5','7','9']:
               flag_digi = 1

  if flag_digi == 0:
     if count == 4 or count == 6:
          res = 'valid '

     else :
             res = 'invalid'

   else :
         return 'invalid'

   return res

print(validate_pin(2425))
# Out:
#   File "<tokenize>", line 21
#     else :
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
def validate_pin(pin):
    res = ''
    count = 0
    flag_digi = 0

    for i in pin:
        count += 1

        if i not in ['1', '3', '5', '7', '9']:
            flag_digi = 1

    if flag_digi == 0:
        if count == 4 or count == 6:
            res = 'valid'
        else:
            res = 'invalid'
    else:
        return 'invalid'

    return res

print(validate_pin('1346'))
# Out:
# invalid
